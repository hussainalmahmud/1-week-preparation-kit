# %% [markdown]
# <a href="https://colab.research.google.com/github/hussainsan/1-week-preparation-kit/blob/main/Day_7/TreeHuffmanDecoding.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import queue as Queue

cntr = 0

class Node:
    def __init__(self, freq, data):
        self.freq = freq
        self.data = data
        self.left = None
        self.right = None
        global cntr
        self._count = cntr
        cntr = cntr + 1
        
    def __lt__(self, other):
        if self.freq != other.freq:
            return self.freq < other.freq
        return self._count < other._count

def huffman_hidden():#builds the tree and returns root
    q = Queue.PriorityQueue()

    
    for key in freq:
        q.put((freq[key], key, Node(freq[key], key) ))
    
    while q.qsize() != 1:
        a = q.get()
        b = q.get()
        obj = Node(a[0] + b[0], '\0' )
        obj.left = a[2]
        obj.right = b[2]
        q.put((obj.freq, obj.data, obj ))
        
    root = q.get()
    root = root[2]#contains root object
    return root

def dfs_hidden(obj, already):
    if(obj == None):
        return
    elif(obj.data != '\0'):
        code_hidden[obj.data] = already
        
    dfs_hidden(obj.right, already + "1")
    dfs_hidden(obj.left, already + "0")

"""class Node:
    def __init__(self, freq,data):
        self.freq= freq
        self.data=data
        self.left = None
        self.right = None
"""        

# Enter your code here. Read input from STDIN. Print output to STDOUT
def decodeHuff(root, s):
	#Enter Your Code Here
    pt = root
    decoded = ''
    for code in s:
        if code == '0':
            pt = pt.left
        elif code == '1':
            pt = pt.right
            
        if not pt.left and not pt.right:
            decoded += pt.data
            pt = root
    print(decoded)
            
ip = input()
freq = {}#maps each character to its frequency

cntr = 0

for ch in ip:
    if(freq.get(ch) == None):
        freq[ch] = 1
    else:
        freq[ch]+=1

root = huffman_hidden()#contains root of huffman tree

code_hidden = {}#contains code for each object

dfs_hidden(root, "")

if len(code_hidden) == 1:#if there is only one character in the i/p
    for key in code_hidden:
        code_hidden[key] = "0"

toBeDecoded = ""

for ch in ip:
    toBeDecoded += code_hidden[ch]

print("Encoded String:", toBeDecoded)
decodeHuff(root, toBeDecoded)
# Out:
# Encoded String: 1001011
# ABACA

# %% [markdown]
#  # Time and Space Complexity of the `decodeHuff` function:
#
# ### Time Complexity:
#
# 1. **Looping through the Encoded String**: The function iterates over the encoded string `s` once. For each character in `s`, it traverses nodes in the Huffman tree. In the worst case, this traversal can go as deep as the height of the tree for each character in `s`. However, the height of a Huffman tree is bounded by ($O(\log n)$), where \(n\) is the number of unique characters (since Huffman trees are generally balanced). Given that the encoded string's length is directly proportional to the input string's length, let's call the length of `s` as \(m\).
#
#    Thus, the time complexity for this operation is $(O(m \log n)$).
#
# 2. **Appending to the Decoded String**: The string concatenation operation `decoded += pt.data` takes \(O(1)\) time for each character. Over the entire string, this would be \(O(m)\).
#
# Combining the above operations, the overall time complexity is $(O(m \log n) + O(m) = O(m \log n)$), where \(m\) is the length of the encoded string `s` and \(n\) is the number of unique characters.
#
# ### Space Complexity:
#
# 1. **Decoded String**: The function constructs the `decoded` string, which, in the end, will have a length equal to the original input string. This takes \(O(m)\) space.
#
# 2. **Constant Space Variables**: Variables like `pt` and `code` take constant space, \(O(1)\).
#
# The dominant factor here is the `decoded` string. Thus, the space complexity is \(O(m)\), where \(m\) is the length of the original input string.
#
# In summary:
# - Time Complexity: $(O(m \log n)$)
# - Space Complexity: $(O(m)$)
